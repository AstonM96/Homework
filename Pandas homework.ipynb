# %% [markdown]
# <h1>Tackling an open problem</h1>
#
# For this homework the idea is to hone our skills on exploring and plotting a dataset. You can either work with the Pokemon dataset that was given or download your own. If you opt to download your own I recommend you use one of the datasets available on kaggle,
#
# https://www.kaggle.com/datasets
#
# As they tend to be found in a clean format and are generally free to use.
#
# Largely, the main objective is learning how to search the internet for new implementations you want to use on your code helping you develop your self-confidence.
#
# There's no right or wrong, pick a dataset you enjoy and try to have some fun.
# If you need, use the notebook from the previous session as a guideline.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
depwork_df = pd.read_csv('depwork.csv', sep=',')

# %%
print(depwork_df)
# Out:
#       Gender  Age  Work Pressure  Job Satisfaction     Sleep Duration  \
# 0     Female   37            2.0               4.0          7-8 hours
# 1       Male   60            4.0               3.0          5-6 hours
# 2     Female   42            2.0               3.0          5-6 hours
# 3     Female   44            3.0               5.0          7-8 hours
# 4       Male   48            4.0               3.0          7-8 hours
# ...      ...  ...            ...               ...                ...
# 2049  Female   45            1.0               3.0  Less than 5 hours
# 2050    Male   25            1.0               5.0          5-6 hours
# 2051  Female   23            3.0               1.0  Less than 5 hours
# 2052  Female   24            1.0               4.0  Less than 5 hours
# 2053  Female   56            2.0               3.0          7-8 hours
#
#      Dietary Habits Have you ever had suicidal thoughts ?  Work Hours  \
# ...

# %%
# Displaying the first 5 rows of the dataframe.
depwork_df.head()
# Out:
#    Gender  Age  Work Pressure  Job Satisfaction Sleep Duration Dietary Habits  \
# 0  Female   37            2.0               4.0      7-8 hours       Moderate
# 1    Male   60            4.0               3.0      5-6 hours      Unhealthy
# 2  Female   42            2.0               3.0      5-6 hours       Moderate
# 3  Female   44            3.0               5.0      7-8 hours        Healthy
# 4    Male   48            4.0               3.0      7-8 hours       Moderate
#
#   Have you ever had suicidal thoughts ?  Work Hours  Financial Stress  \
# 0                                    No           6                 2
# 1                                   Yes           0                 4
# 2                                    No           0                 2
# 3                                   Yes           1                 2
# 4                                   Yes           6                 5
#
#   Family History of Mental Illness Depression
# ...

# %%
# Displaying the first 5 rows of the dataframe.
depwork_df.tail()
# Out:
#       Gender  Age  Work Pressure  Job Satisfaction     Sleep Duration  \
# 2049  Female   45            1.0               3.0  Less than 5 hours
# 2050    Male   25            1.0               5.0          5-6 hours
# 2051  Female   23            3.0               1.0  Less than 5 hours
# 2052  Female   24            1.0               4.0  Less than 5 hours
# 2053  Female   56            2.0               3.0          7-8 hours
#
#      Dietary Habits Have you ever had suicidal thoughts ?  Work Hours  \
# 2049        Healthy                                   Yes           2
# 2050        Healthy                                   Yes          12
# 2051       Moderate                                   Yes           8
# 2052       Moderate                                   Yes           4
# 2053        Healthy                                    No           4
#
#       Financial Stress Family History of Mental Illness Depression
# ...

# %%
depwork_df.describe()
# Out:
#                Age  Work Pressure  Job Satisfaction   Work Hours  \
# count  2054.000000    2054.000000       2054.000000  2054.000000
# mean     42.171860       3.021908          3.015093     5.930867
# std      11.461202       1.417312          1.418432     3.773945
# min      18.000000       1.000000          1.000000     0.000000
# 25%      35.000000       2.000000          2.000000     3.000000
# 50%      43.000000       3.000000          3.000000     6.000000
# 75%      51.750000       4.000000          4.000000     9.000000
# max      60.000000       5.000000          5.000000    12.000000
#
#        Financial Stress
# count       2054.000000
# mean           2.978578
# std            1.413362
# min            1.000000
# 25%            2.000000
# 50%            3.000000
# 75%            4.000000
# max            5.000000

# %%
depwork_df.keys()
# Out:
# Index(['Gender', 'Age', 'Work Pressure', 'Job Satisfaction', 'Sleep Duration',
#        'Dietary Habits', 'Have you ever had suicidal thoughts ?', 'Work Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')

# %%
depwork_df['Dietary Habits'].unique()
# Out:
# array(['Moderate', 'Unhealthy', 'Healthy'], dtype=object)

# %%
depwork_df['Dietary Habits'].value_counts()
# Out:
# Dietary Habits
# Unhealthy    713
# Healthy      681
# Moderate     660
# Name: count, dtype: int64

# %%
depwork_df['Sleep Duration'].unique()
# Out:
# array(['7-8 hours', '5-6 hours', 'More than 8 hours', 'Less than 5 hours'],
#       dtype=object)

# %%
depwork_df['Sleep Duration'].value_counts()
# Out:
# Sleep Duration
# 7-8 hours            530
# Less than 5 hours    525
# 5-6 hours            505
# More than 8 hours    494
# Name: count, dtype: int64

# %%
print(depwork_df[['Work Pressure',"Depression"]].value_counts())
# Out:
# Work Pressure  Depression
# 2.0            No            393
# 1.0            No            388
# 3.0            No            372
# 4.0            No            358
# 5.0            No            340
#                Yes            84
# 4.0            Yes            54
# 3.0            Yes            32
# 2.0            Yes            20
# 1.0            Yes            13
# Name: count, dtype: int64

# %%
print("Data Exploration:")
print(f"Total Entries: {len(depwork_df)}")
print(f"Data Types:\n{depwork_df.dtypes}")
# Out:
# Data Exploration:
# Total Entries: 2054
# Data Types:
# Gender                                    object
# Age                                        int64
# Work Pressure                            float64
# Job Satisfaction                         float64
# Sleep Duration                            object
# Dietary Habits                            object
# Have you ever had suicidal thoughts ?     object
# Work Hours                                 int64
# Financial Stress                           int64
# Family History of Mental Illness          object
# Depression                                object
# dtype: object

# %%
# Handle missing values
print("\nHandling Missing Values:")
print(depwork_df.isnull().sum())
# Implement your missing value handling strategy here (e.g., drop rows, impute values)
df = depwork_df.dropna()
# Out:
# Handling Missing Values:
# Gender                                   0
# Age                                      0
# Work Pressure                            0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Have you ever had suicidal thoughts ?    0
# Work Hours                               0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
print("\nCategorical Features:")
print(depwork_df.describe(include='O'))
# Out:
# Categorical Features:
#        Gender Sleep Duration Dietary Habits  \
# count    2054           2054           2054
# unique      2              4              3
# top      Male      7-8 hours      Unhealthy
# freq     1066            530            713
#
#        Have you ever had suicidal thoughts ? Family History of Mental Illness  \
# count                                   2054                             2054
# unique                                     2                                2
# top                                       No                               No
# freq                                    1065                             1046
#
#        Depression
# count        2054
# unique          2
# top            No
# freq         1851

# %%
depwork_df.hist()
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Work Pressure'}>],
#        [<Axes: title={'center': 'Job Satisfaction'}>,
#         <Axes: title={'center': 'Work Hours'}>],
#        [<Axes: title={'center': 'Financial Stress'}>, <Axes: >]],
#       dtype=object)

# %%
depwork_df.hist('Work Pressure')
# Out:
# array([[<Axes: title={'center': 'Work Pressure'}>]], dtype=object)

# %%
depwork_df['Work Pressure'].value_counts()
# Out:
# Work Pressure
# 5.0    424
# 2.0    413
# 4.0    412
# 3.0    404
# 1.0    401
# Name: count, dtype: int64

# %%
sns.countplot(x='Gender', hue='Depression', data=df)
plt.title('Depression by Gender')
plt.show()

# %%
sns.countplot(x='Age', hue='Financial Stress', data=df)
plt.title('Depression by Gender')
plt.show()

# %%
sns.countplot(x='Gender', hue='Work Pressure', data=df)
plt.title('Work Pressure by Gender')
plt.show()

# %%
sns.countplot(x='Work Pressure', hue='Depression', data=df)
plt.title('Depression by Work Pressure')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Age', y='Work Pressure', hue='Depression', data=df)
plt.title('Depression by Age and Work Pressure')
plt.show()

# %%
plt.figure(figsize=(8, 6))
scatter = plt.scatter(
    depwork_df['Sleep Duration'], 
    depwork_df['Depression'],)

#want to understand why scatter graphs arent working? is it just the way i am looking at data?

# %%
sns.boxplot(x=depwork_df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(x=depwork_df['Financial Stress'])
# Out:
# <Axes: xlabel='Financial Stress'>

# %%
depwork_df['Have you ever had suicidal thoughts ?'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(7, 7))
# Out:
# <Axes: ylabel='count'>

# %%
depwork_df["Have you ever had suicidal thoughts ?"].value_counts()
# Out:
# Have you ever had suicidal thoughts ?
# No     1065
# Yes     989
# Name: count, dtype: int64
